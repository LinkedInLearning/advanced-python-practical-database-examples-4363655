# %%
import pandas as pd

# %%
df = pd.read_csv("red30.csv")

# %%
import matplotlib

# %%
df['Quantity'].hist()
# Out:
# <Axes: >

# %%
df['ProdCategory'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >
